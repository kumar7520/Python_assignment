# %% [markdown]
# ## 2. Consider the following problem:
# ## 𝑓(𝑥1, 𝑥2) = $4X1 + 6X2 -2X1^2 -2X1X2 - 2X2^2$

# %% [markdown]
# ## A )Vizualising The Function

# %% [markdown]
# ## 1. a) Formulate the problem in the Excel file and generate the sensitivity analysis

# %% [markdown]
# ## Max  7x1 + 10x2
#
# ## subject to :
# ## x1<=500
# ##  x2<=500
# ## 5x1 + 6x2 <=3600
# ## x1+ 2x2 <=960

# %% [markdown]
# ![Annotation%202022-11-14%20155412.png](attachment:Annotation%202022-11-14%20155412.png)

# %% [markdown]
# ![se.png](attachment:se.png)

# %% [markdown]
# ## 1b) Write on cost coefficient sensitivity analysis.

# %% [markdown]
# ## The analysis says we can increase the objectve function of softball to 8.3 max and 14 of base ball to get maximum price
# ## -> if Decrease the coeffiecent of x1 to 5 and x2 to 8.4 we get profit 4320
# ## -> if we increase the coeffecirnt of x1 to 8.3 and x2 to 14 we get profit 7188

# %% [markdown]
# ![Annotation%202022-11-14%20161114.png](attachment:Annotation%202022-11-14%20161114.png)

# %% [markdown]
# ![Annotation%202022-11-14%20161247.png](attachment:Annotation%202022-11-14%20161247.png)

# %% [markdown]
# ## 1c) Write on Right Hand Side Sensitivity Analysis.

# %% [markdown]
# ## The Maximum allowable increase in righ hand side constraint is 280 and decrease is 720 for constraint 1
# ## The Maximum allowable Increase for constraint 2 is 160 and decrease is  93.33
# ## for constraint 3 allowable increase is 1E +30 And Decrease is 140
# ## For Constraint 4 Allowable increase is 1E +30 and decrease is 200

# %% [markdown]
# ![Annotation%202022-11-14%20162712.png](attachment:Annotation%202022-11-14%20162712.png)
